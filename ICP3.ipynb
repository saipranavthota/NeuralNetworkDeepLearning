# %%
# Imports
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the Breast Cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=87)

# Neural network model with additional dense layers
model = Sequential()
model.add(Dense(20, input_dim=X_train.shape[1], activation='relu'))  # Adjusted input_dim for Breast Cancer dataset
model.add(Dense(64, activation='relu'))  # Additional dense layer
model.add(Dense(64, activation='relu'))  # Additional dense layer
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, Y_train, epochs=100, batch_size=10, verbose=1)

# Model summary
print(model.summary())

# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
print(f'Test Accuracy: {accuracy*100:.2f}%')
# Out:
# Epoch 1/100
# 43/43 [==============================] - 4s 9ms/step - loss: 0.4594 - accuracy: 0.8333
# Epoch 2/100
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1411 - accuracy: 0.9531
# Epoch 3/100
# 43/43 [==============================] - 0s 9ms/step - loss: 0.0776 - accuracy: 0.9695
# Epoch 4/100
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0608 - accuracy: 0.9789
# Epoch 5/100
# 43/43 [==============================] - 0s 9ms/step - loss: 0.0522 - accuracy: 0.9812
# Epoch 6/100
# 43/43 [==============================] - 0s 10ms/step - loss: 0.0429 - accuracy: 0.9883
# Epoch 7/100
# 43/43 [==============================] - 0s 8ms/step - loss: 0.0356 - accuracy: 0.9906
# Epoch 8/100
# 43/43 [==============================] - 0s 9ms/step - loss: 0.0308 - accuracy: 0.9906
# Epoch 9/100
# 43/43 [==============================] - 0s 9ms/step - loss: 0.0259 - accuracy: 0.9930
# Epoch 10/100
# 43/43 [==============================] - 0s 10ms/step - loss: 0.0220 - accuracy: 0.9930
# Epoch 11/100
# 43/43 [==============================] - 0s 9ms/step - loss: 0.0193 - accuracy: 0.9953
# Epoch 12/100
# 43/43 [==============================] - 0s 10ms/step - loss: 0.0172 - accuracy: 0.9953
# Epoch 13/100
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0145 - accuracy: 0.9953
# Epoch 14/100
# 43/43 [==============================] - 0s 10ms/step - loss: 0.0123 - accuracy: 0.9953
# Epoch 15/100
# 43/43 [==============================] - 0s 11ms/step - loss: 0.0118 - accuracy: 0.9953
# Epoch 16/100
# 43/43 [==============================] - 0s 8ms/step - loss: 0.0089 - accuracy: 0.9977
# Epoch 17/100
# 43/43 [==============================] - 0s 9ms/step - loss: 0.0074 - accuracy: 0.9953
# Epoch 18/100
# 43/43 [==============================] - 0s 8ms/step - loss: 0.0064 - accuracy: 0.9977
# Epoch 19/100
# 43/43 [==============================] - 0s 11ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 20/100
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 21/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 22/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 23/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 24/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 25/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 26/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 27/100
# 43/43 [==============================] - 0s 2ms/step - loss: 9.7956e-04 - accuracy: 1.0000
# Epoch 28/100
# 43/43 [==============================] - 0s 2ms/step - loss: 9.0386e-04 - accuracy: 1.0000
# Epoch 29/100
# 43/43 [==============================] - 0s 2ms/step - loss: 7.7019e-04 - accuracy: 1.0000
# Epoch 30/100
# 43/43 [==============================] - 0s 2ms/step - loss: 6.2907e-04 - accuracy: 1.0000
# Epoch 31/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.7745e-04 - accuracy: 1.0000
# Epoch 32/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.0221e-04 - accuracy: 1.0000
# Epoch 33/100
# 43/43 [==============================] - 0s 3ms/step - loss: 4.5064e-04 - accuracy: 1.0000
# Epoch 34/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.1569e-04 - accuracy: 1.0000
# Epoch 35/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.6810e-04 - accuracy: 1.0000
# Epoch 36/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.4490e-04 - accuracy: 1.0000
# Epoch 37/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.1438e-04 - accuracy: 1.0000
# Epoch 38/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.8534e-04 - accuracy: 1.0000
# Epoch 39/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.5616e-04 - accuracy: 1.0000
# Epoch 40/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.4000e-04 - accuracy: 1.0000
# Epoch 41/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.2375e-04 - accuracy: 1.0000
# Epoch 42/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.0555e-04 - accuracy: 1.0000
# Epoch 43/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.9344e-04 - accuracy: 1.0000
# Epoch 44/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.7264e-04 - accuracy: 1.0000
# Epoch 45/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.5959e-04 - accuracy: 1.0000
# Epoch 46/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.4972e-04 - accuracy: 1.0000
# Epoch 47/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.4333e-04 - accuracy: 1.0000
# Epoch 48/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.3135e-04 - accuracy: 1.0000
# Epoch 49/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.2273e-04 - accuracy: 1.0000
# Epoch 50/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.1623e-04 - accuracy: 1.0000
# Epoch 51/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.1024e-04 - accuracy: 1.0000
# Epoch 52/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.0248e-04 - accuracy: 1.0000
# Epoch 53/100
# 43/43 [==============================] - 0s 2ms/step - loss: 9.7397e-05 - accuracy: 1.0000
# Epoch 54/100
# 43/43 [==============================] - 0s 2ms/step - loss: 9.1180e-05 - accuracy: 1.0000
# Epoch 55/100
# 43/43 [==============================] - 0s 2ms/step - loss: 8.6670e-05 - accuracy: 1.0000
# Epoch 56/100
# 43/43 [==============================] - 0s 2ms/step - loss: 8.1448e-05 - accuracy: 1.0000
# Epoch 57/100
# 43/43 [==============================] - 0s 2ms/step - loss: 7.7700e-05 - accuracy: 1.0000
# Epoch 58/100
# 43/43 [==============================] - 0s 2ms/step - loss: 7.7557e-05 - accuracy: 1.0000
# Epoch 59/100
# 43/43 [==============================] - 0s 2ms/step - loss: 7.1119e-05 - accuracy: 1.0000
# Epoch 60/100
# 43/43 [==============================] - 0s 2ms/step - loss: 6.5376e-05 - accuracy: 1.0000
# Epoch 61/100
# 43/43 [==============================] - 0s 2ms/step - loss: 6.2785e-05 - accuracy: 1.0000
# Epoch 62/100
# 43/43 [==============================] - 0s 2ms/step - loss: 6.0096e-05 - accuracy: 1.0000
# Epoch 63/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.7357e-05 - accuracy: 1.0000
# Epoch 64/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.3961e-05 - accuracy: 1.0000
# Epoch 65/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.1596e-05 - accuracy: 1.0000
# Epoch 66/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.9138e-05 - accuracy: 1.0000
# Epoch 67/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.7312e-05 - accuracy: 1.0000
# Epoch 68/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.4915e-05 - accuracy: 1.0000
# Epoch 69/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.3081e-05 - accuracy: 1.0000
# Epoch 70/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.1940e-05 - accuracy: 1.0000
# Epoch 71/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.0027e-05 - accuracy: 1.0000
# Epoch 72/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.7689e-05 - accuracy: 1.0000
# Epoch 73/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.6385e-05 - accuracy: 1.0000
# Epoch 74/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.4938e-05 - accuracy: 1.0000
# Epoch 75/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.2908e-05 - accuracy: 1.0000
# Epoch 76/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.2474e-05 - accuracy: 1.0000
# Epoch 77/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.1877e-05 - accuracy: 1.0000
# Epoch 78/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.9097e-05 - accuracy: 1.0000
# Epoch 79/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.7895e-05 - accuracy: 1.0000
# Epoch 80/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.7542e-05 - accuracy: 1.0000
# Epoch 81/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.6077e-05 - accuracy: 1.0000
# Epoch 82/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.5051e-05 - accuracy: 1.0000
# Epoch 83/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.4029e-05 - accuracy: 1.0000
# Epoch 84/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.3205e-05 - accuracy: 1.0000
# Epoch 85/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.2466e-05 - accuracy: 1.0000
# Epoch 86/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.1537e-05 - accuracy: 1.0000
# Epoch 87/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.0707e-05 - accuracy: 1.0000
# Epoch 88/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.9929e-05 - accuracy: 1.0000
# Epoch 89/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.9125e-05 - accuracy: 1.0000
# Epoch 90/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.8424e-05 - accuracy: 1.0000
# Epoch 91/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.7588e-05 - accuracy: 1.0000
# Epoch 92/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.7043e-05 - accuracy: 1.0000
# Epoch 93/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.6358e-05 - accuracy: 1.0000
# Epoch 94/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.5961e-05 - accuracy: 1.0000
# Epoch 95/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.5328e-05 - accuracy: 1.0000
# Epoch 96/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.4955e-05 - accuracy: 1.0000
# Epoch 97/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.4252e-05 - accuracy: 1.0000
# Epoch 98/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.3725e-05 - accuracy: 1.0000
# Epoch 99/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.3225e-05 - accuracy: 1.0000
# Epoch 100/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.2820e-05 - accuracy: 1.0000
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                620
#
#  dense_1 (Dense)             (None, 64)                1344
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 6189 (24.18 KB)
# Trainable params: 6189 (24.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Test Accuracy: 96.50%

# %%
from keras.datasets import mnist
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Preprocess the data
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0], dimData).astype('float32') / 255
test_data = test_images.reshape(test_images.shape[0], dimData).astype('float32') / 255
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# Creating the network
model = Sequential([
    Dense(512, activation='relu', input_shape=(dimData,)),
    Dense(512, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                    validation_data=(test_data, test_labels_one_hot))

# Plotting the accuracy and loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()
plt.show()

# Predicting a single image
def predict_single_image(image_data):
    image_data = image_data.reshape(1, dimData).astype('float32') / 255
    prediction = model.predict(image_data)
    predicted_class = np.argmax(prediction)
    return predicted_class

# Choose an image from the test set
image_index = 0  # Change this to see different predictions
predicted_class = predict_single_image(test_images[image_index])
print(f'Predicted class for image at index {image_index}: {predicted_class}')
plt.imshow(test_images[image_index], cmap='gray')
plt.title(f'Image at index {image_index} - Predicted as: {predicted_class}')
plt.show()

# Modify the model to use different activation functions and fewer layers for comparison
# You can adjust the following model architecture as needed
model_tanh = Sequential([
    Dense(512, activation='tanh', input_shape=(dimData,)),
    Dense(10, activation='softmax')
])

model_tanh.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model_tanh.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
               validation_data=(test_data, test_labels_one_hot))

# To compare performance without scaling, you would need to adjust the data preprocessing
# and re-train the model. This is not included here for brevity but can be done by removing
# the division by 255 in the data preprocessing steps.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 235/235 [==============================] - 9s 31ms/step - loss: 0.2902 - accuracy: 0.9113 - val_loss: 0.1507 - val_accuracy: 0.9549
# Epoch 2/10
# 235/235 [==============================] - 8s 34ms/step - loss: 0.0999 - accuracy: 0.9699 - val_loss: 0.0940 - val_accuracy: 0.9714
# Epoch 3/10
# 235/235 [==============================] - 6s 25ms/step - loss: 0.0639 - accuracy: 0.9798 - val_loss: 0.0944 - val_accuracy: 0.9694
# Epoch 4/10
# 235/235 [==============================] - 8s 35ms/step - loss: 0.0434 - accuracy: 0.9862 - val_loss: 0.0595 - val_accuracy: 0.9820
# Epoch 5/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0305 - accuracy: 0.9902 - val_loss: 0.0764 - val_accuracy: 0.9778
# Epoch 6/10
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0223 - accuracy: 0.9930 - val_loss: 0.0881 - val_accuracy: 0.9757
# Epoch 7/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 0.0646 - val_accuracy: 0.9816
# Epoch 8/10
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 0.0743 - val_accuracy: 0.9824
# Epoch 9/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0764 - val_accuracy: 0.9809
# Epoch 10/10
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0778 - val_accuracy: 0.9794
# 1/1 [==============================] - 0s 144ms/step
# Predicted class for image at index 0: 7
# Epoch 1/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3910 - accuracy: 0.8862 - val_loss: 0.2567 - val_accuracy: 0.9256
# Epoch 2/10
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2312 - accuracy: 0.9323 - val_loss: 0.1937 - val_accuracy: 0.9440
# Epoch 3/10
# 235/235 [==============================] - 5s 20ms/step - loss: 0.1672 - accuracy: 0.9522 - val_loss: 0.1589 - val_accuracy: 0.9528
# Epoch 4/10
# 235/235 [==============================] - 5s 20ms/step - loss: 0.1266 - accuracy: 0.9628 - val_loss: 0.1288 - val_accuracy: 0.9591
# Epoch 5/10
# 235/235 [==============================] - 4s 15ms/step - loss: 0.1018 - accuracy: 0.9710 - val_loss: 0.1035 - val_accuracy: 0.9689
# Epoch 6/10
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0831 - accuracy: 0.9754 - val_loss: 0.0902 - val_accuracy: 0.9721
# Epoch 7/10
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0688 - accuracy: 0.9803 - val_loss: 0.0994 - val_accuracy: 0.9682
# Epoch 8/10
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0580 - accuracy: 0.9836 - val_loss: 0.0870 - val_accuracy: 0.9730
# Epoch 9/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0491 - accuracy: 0.9858 - val_loss: 0.0752 - val_accuracy: 0.9768
# Epoch 10/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0417 - accuracy: 0.9883 - val_loss: 0.0696 - val_accuracy: 0.9771
